# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
data = pd.read_csv(r"D:\Excel\study_analys.csv")
print(data)
# Out:
#                           Timestamp                  NAME      CLASS/SEC  \
# 0    2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1    2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2    2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3    2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4    2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
# ..                              ...                   ...            ...
# 145  2023/05/13 3:01:09 pm GMT+5:30              Priya PT     2nd bcom D
# 146  2023/05/13 6:14:00 pm GMT+5:30              Krithika        2nd BBA
# 147  2023/05/14 3:07:27 pm GMT+5:30               Thrisha       1 bcom c
# 148  2023/05/12 8:44:09 pm GMT+5:30             niveditha         1 bcom
# 149  2023/05/12 8:09:12 pm GMT+5:30         Deevitha H D    2nd bcom 'c'
#
#      ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4                Q5  Q6  Q7  Q8
# ...

# %% [markdown]
# Q1= which one is more preferable social media sites for use,
# Q2= Hours spend to using social media sites per day,
# Q3 Purpose of using social media sites?,
# Q4= Benefits of using social networking sites?,
# Q5= Disadvantage of using social networking sites?,
# Q6= do you think privacy policies are effective in social networking sites?,
# Q7= Do you accept strangers who try to friend you on social networking sites?,
# Q8= To what extent do you think social networking sites are impacting your over all well being?

# %%
data.head()
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 0       220721       1   2   1  3  3  4   3   2   1
# 1       210875       1   2   1  1  3  5   4   2   1
# 2       210337       1   3   1  1  3  4   4   2   1
# 3       210780       1   3   1  1  2  1   1   2   1
# 4       210743       1   3   1  1  2  4   2   3   1

# %%
data.tail()
# Out:
#                           Timestamp           NAME     CLASS/SEC  ROLL NUMBER  \
# 145  2023/05/13 3:01:09 pm GMT+5:30       Priya PT    2nd bcom D       210843
# 146  2023/05/13 6:14:00 pm GMT+5:30       Krithika       2nd BBA       211072
# 147  2023/05/14 3:07:27 pm GMT+5:30        Thrisha      1 bcom c       220748
# 148  2023/05/12 8:44:09 pm GMT+5:30      niveditha        1 bcom       220721
# 149  2023/05/12 8:09:12 pm GMT+5:30  Deevitha H D   2nd bcom 'c'       210713
#
#      GENDER  Q1  Q2 Q3 Q4                Q5  Q6  Q7  Q8
# 145       2   3   3  1  2                 4   1   2   4
# 146       2   3   3  4  2                 2   2   1   4
# 147       2   3   3  1  2  All of the above   2   2   4
# 148       2   3   3  1  2                 4   2   3   4
# 149       2   5   3  3  2                 2   2   2   4

# %%
data.isnull()
# Out:
#      Timestamp   NAME  CLASS/SEC  ROLL NUMBER  GENDER     Q1     Q2     Q3  \
# 0        False  False      False        False   False  False  False  False
# 1        False  False      False        False   False  False  False  False
# 2        False  False      False        False   False  False  False  False
# 3        False  False      False        False   False  False  False  False
# 4        False  False      False        False   False  False  False  False
# ..         ...    ...        ...          ...     ...    ...    ...    ...
# 145      False  False      False        False   False  False  False  False
# 146      False  False      False        False   False  False  False  False
# 147      False  False      False        False   False  False  False  False
# 148      False  False      False        False   False  False  False  False
# 149      False  False      False        False   False  False  False  False
#
#         Q4     Q5     Q6     Q7     Q8
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    150 non-null    object
#  1   NAME         150 non-null    object
#  2   CLASS/SEC    150 non-null    object
#  3   ROLL NUMBER  150 non-null    int64
#  4   GENDER       150 non-null    int64
#  5   Q1           150 non-null    int64
#  6   Q2           150 non-null    int64
#  7   Q3           150 non-null    object
#  8   Q4           150 non-null    object
#  9   Q5           150 non-null    object
#  10  Q6           150 non-null    int64
#  11  Q7           150 non-null    int64
#  12  Q8           150 non-null    int64
# dtypes: int64(7), object(6)
# memory usage: 15.4+ KB

# %%
data.dtypes
# Out:
# Timestamp      object
# NAME           object
# CLASS/SEC      object
# ROLL NUMBER     int64
# GENDER          int64
# Q1              int64
# Q2              int64
# Q3             object
# Q4             object
# Q5             object
# Q6              int64
# Q7              int64
# Q8              int64
# dtype: object

# %%
data.shape
# Out:
# (150, 13)

# %%
data.size
# Out:
# 1950

# %%
data.columns
# Out:
# Index(['Timestamp', 'NAME', 'CLASS/SEC', 'ROLL NUMBER', 'GENDER', 'Q1', 'Q2',
#        'Q3', 'Q4', 'Q5', 'Q6', 'Q7', 'Q8'],
#       dtype='object')

# %% [markdown]
# #Data cleaning

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
data.drop_duplicates()
# Out:
#                           Timestamp                  NAME      CLASS/SEC  \
# 0    2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1    2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2    2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3    2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4    2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
# ..                              ...                   ...            ...
# 145  2023/05/13 3:01:09 pm GMT+5:30              Priya PT     2nd bcom D
# 146  2023/05/13 6:14:00 pm GMT+5:30              Krithika        2nd BBA
# 147  2023/05/14 3:07:27 pm GMT+5:30               Thrisha       1 bcom c
# 148  2023/05/12 8:44:09 pm GMT+5:30             niveditha         1 bcom
# 149  2023/05/12 8:09:12 pm GMT+5:30         Deevitha H D    2nd bcom 'c'
#
#      ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4                Q5  Q6  Q7  Q8
# ...

# %%
data.drop_duplicates(inplace=True)  # to remove the Duplicate rows parmanetly

# %%
data.isnull().sum()
# Out:
# Timestamp      0
# NAME           0
# CLASS/SEC      0
# ROLL NUMBER    0
# GENDER         0
# Q1             0
# Q2             0
# Q3             0
# Q4             0
# Q5             0
# Q6             0
# Q7             0
# Q8             0
# dtype: int64

# %%
import seaborn as sns  # to import seaborn library
from matplotlib import pyplot as mt

# %%
sns.heatmap(data.isnull())  # using Heat- map to show null values count
# Out:
# <Axes: >

# %% [markdown]
# Sorting Data

# %%
data.sort_values(by=['Q5'])   # sroting values by Q5
# Out:
#                            Timestamp              NAME           CLASS/SEC  \
# 40   2023/05/12 10:14:26 pm GMT+5:30      Melvin P Tom          2nd Bcom C
# 76    2023/05/13 8:09:51 am GMT+5:30         Sanjay DK           2nd Bsc B
# 135   2023/05/13 3:56:28 pm GMT+5:30     Deepthi Jain        2nd B.Com 'A'
# 12    2023/05/12 6:42:22 pm GMT+5:30          Panchami          2nd Bcom D
# 73    2023/05/12 8:22:23 pm GMT+5:30        Adarsh A R            2 BCOM C
# ..                               ...               ...                 ...
# 31   2023/05/11 10:30:17 pm GMT+5:30          Varsha J  Second year B.Sc A
# 61    2023/05/12 7:02:10 pm GMT+5:30  Shreeram Marathe           3rd BSc A
# 52    2023/05/12 8:47:06 pm GMT+5:30         Ma2j B R              1 B.Com
# 147   2023/05/14 3:07:27 pm GMT+5:30           Thrisha            1 bcom c
# 113   2023/05/12 6:48:09 pm GMT+5:30       Archana P P         2nd B.com D
#
#      ROLL NUMBER  GENDER  Q1  Q2  \
# ...

# %% [markdown]
# Q1. For "Panchami" , what is the Roll Number ,Class/sec and answers of all quation?

# %%
data[data['NAME'].isin(['Panchami'])]  # TO show records of a particular item in  any column
# Out:
#                          Timestamp      NAME   CLASS/SEC  ROLL NUMBER  GENDER  \
# 12  2023/05/12 6:42:22 pm GMT+5:30  Panchami  2nd Bcom D       210837       2
#
#     Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 12   3   1  4  2  1   2   3   1

# %%
data[data['Timestamp'].isin(['2023/05/12 8:29:52 pm GMT+5:30'])] # TO show records of a particular item in  any column
# Out:
#                         Timestamp           NAME      CLASS/SEC  ROLL NUMBER  \
# 0  2023/05/12 8:29:52 pm GMT+5:30  Mukesh kulal   1st b.com 'C'       220721
#
#    GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 0       1   2   1  3  3  4   3   2   1

# %%
data.Q5
# Out:
# 0                     4
# 1                     5
# 2                     4
# 3                     1
# 4                     4
#              ...
# 145                   4
# 146                   2
# 147    All of the above
# 148                   4
# 149                   2
# Name: Q5, Length: 150, dtype: object

# %% [markdown]
# # str.contains()

# %%
data[data['NAME'].str.contains('Sanjay DK')]   # To show records of a particular string in any column
# Out:
#                          Timestamp       NAME  CLASS/SEC  ROLL NUMBER  GENDER  \
# 76  2023/05/13 8:09:51 am GMT+5:30  Sanjay DK  2nd Bsc B       210406       1
#
#     Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 76   2   4  1  3  1   4   1   4

# %%
data.sort_values(by=['Timestamp'])
# Out:
#                            Timestamp            NAME           CLASS/SEC  \
# 31   2023/05/11 10:30:17 pm GMT+5:30        Varsha J  Second year B.Sc A
# 75    2023/05/11 7:22:42 pm GMT+5:30  Navaneeth A N             2nd B.Sc
# 30    2023/05/11 7:26:50 pm GMT+5:30   Jeevitha S K                BSc B
# 24    2023/05/11 7:27:10 pm GMT+5:30    Navaneeth S            2nd Bsc B
# 92    2023/05/11 7:27:35 pm GMT+5:30          Manasa           II B.Sc B
# ..                               ...             ...                 ...
# 147   2023/05/14 3:07:27 pm GMT+5:30         Thrisha            1 bcom c
# 49    2023/05/14 4:10:03 pm GMT+5:30       Amith M G             3rd BBA
# 115   2023/05/14 9:37:42 am GMT+5:30     Dhanyashree              2b.com
# 10    2023/05/14 9:48:15 am GMT+5:30   Hithashree k     2 nd b.com b sec
# 68    2023/05/15 3:09:31 pm GMT+5:30      Sumanth BJ            3rd Bvoc
#
#      ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4                Q5  Q6  Q7  Q8
# ...

# %% [markdown]
# Q.2 In which number highest of therepeted in  Q1 and Q2? show bar Graph

# %%
data.dtypes
# Out:
# Timestamp      object
# NAME           object
# CLASS/SEC      object
# ROLL NUMBER     int64
# GENDER          int64
# Q1              int64
# Q2              int64
# Q3             object
# Q4             object
# Q5             object
# Q6              int64
# Q7              int64
# Q8              int64
# dtype: object

# %%
data['Q1'].value_counts() # counts the occurrence of all individual number in data column
# Out:
# Q1
# 3    72
# 2    51
# 5    12
# 1     9
# 6     6
# Name: count, dtype: int64

# %% [markdown]
# # Bar Graph

# %%
data['Q1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Q1'>

# %% [markdown]
# #  Q.3  How many Boys And Girls are there in the Gender column?

# %%
data.head(5)
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 0       220721       1   2   1  3  3  4   3   2   1
# 1       210875       1   2   1  1  3  5   4   2   1
# 2       210337       1   3   1  1  3  4   4   2   1
# 3       210780       1   3   1  1  2  1   1   2   1
# 4       210743       1   3   1  1  2  4   2   3   1

# %%
data.groupby('GENDER')

# %%
data.groupby('GENDER').GENDER.count() # to show all unique items of a column and thier count
# Out:
# GENDER
# 1    56
# 2    94
# Name: GENDER, dtype: int64

# %%
data.dtypes
# Out:
# Timestamp      object
# NAME           object
# CLASS/SEC      object
# ROLL NUMBER     int64
# GENDER          int64
# Q1              int64
# Q2              int64
# Q3             object
# Q4             object
# Q5             object
# Q6              int64
# Q7              int64
# Q8              int64
# dtype: object

# %%
import numpy as np
df=pd.DataFrame(data)

# %%
filtered_data =data[(data["GENDER"] == 1) & (data['Q6'] == 1)]
filtered_data.count()
#print(filtered_data)
# Out:
# Timestamp      19
# NAME           19
# CLASS/SEC      19
# ROLL NUMBER    19
# GENDER         19
# Q1             19
# Q2             19
# Q3             19
# Q4             19
# Q5             19
# Q6             19
# Q7             19
# Q8             19
# dtype: int64

# %% [markdown]
# Above Reslut shows that 19 male student pick answer 1 in quation Q6

# %%
data.head(3)
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8
# 0       220721       1   2   1  3  3  4   3   2   1
# 1       210875       1   2   1  1  3  5   4   2   1
# 2       210337       1   3   1  1  3  4   4   2   1

# %%
data['Data_N'] = pd.to_datetime(data['Timestamp'])
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_11944\1429890641.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Data_N'] = pd.to_datetime(data['Timestamp'])

# %%
data.head(3)
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30

# %%
data.groupby('Data_N')

# %%
data.groupby('Data_N').Data_N.count()
# Out:
# Data_N
# 2023-05-11 19:22:42-05:30    1
# 2023-05-11 19:26:50-05:30    1
# 2023-05-11 19:27:10-05:30    1
# 2023-05-11 19:27:35-05:30    1
# 2023-05-11 19:40:30-05:30    1
#                             ..
# 2023-05-14 10:30:49-05:30    1
# 2023-05-14 13:05:40-05:30    1
# 2023-05-14 15:07:27-05:30    1
# 2023-05-14 16:10:03-05:30    1
# 2023-05-15 15:09:31-05:30    1
# Name: Data_N, Length: 149, dtype: int64

# %%
data['Data_N'].dt.date.value_counts()
# Out:
# Data_N
# 2023-05-12    78
# 2023-05-13    56
# 2023-05-11     9
# 2023-05-14     6
# 2023-05-15     1
# Name: count, dtype: int64

# %%
data.head(3)
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30

# %%
data['date']= data['Data_N'].dt.date

# %%
data.head(3)
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N  \
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30
#
#          date
# 0  2023-05-12
# 1  2023-05-12
# 2  2023-05-12

# %% [markdown]
# #  Show all the male reaction  and count number of the  students

# %%
filtered_data =data[(data["GENDER"] == 1)]
#print(filtered_data)
filtered_data.count()
# Out:
# Timestamp      56
# NAME           56
# CLASS/SEC      56
# ROLL NUMBER    56
# GENDER         56
# Q1             56
# Q2             56
# Q3             56
# Q4             56
# Q5             56
# Q6             56
# Q7             56
# Q8             56
# Data_N         56
# date           56
# dtype: int64

# %%
filtered_data =data[(data["GENDER"] == 2)]
#print(filtered_data)
filtered_data.count()
# Out:
# Timestamp      94
# NAME           94
# CLASS/SEC      94
# ROLL NUMBER    94
# GENDER         94
# Q1             94
# Q2             94
# Q3             94
# Q4             94
# Q5             94
# Q6             94
# Q7             94
# Q8             94
# Data_N         94
# date           94
# dtype: int64

# %%
data.head()
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N  \
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30
# 3       210780       1   3   1  1  2  1   1   2   1 2023-05-12 19:59:22-05:30
# 4       210743       1   3   1  1  2  4   2   3   1 2023-05-12 20:00:24-05:30
#
#          date
# 0  2023-05-12
# 1  2023-05-12
# 2  2023-05-12
# ...

# %%
data.dtypes
# Out:
# Timestamp                         object
# NAME                              object
# CLASS/SEC                         object
# ROLL NUMBER                        int64
# GENDER                             int64
# Q1                                 int64
# Q2                                 int64
# Q3                                object
# Q4                                object
# Q5                                object
# Q6                                 int64
# Q7                                 int64
# Q8                                 int64
# Data_N         datetime64[ns, UTC-05:30]
# date                              object
# dtype: object

# %%
filtered_data =data[(data["GENDER"] == 1) & (data['Q6'] == 1)]
filtered_data.count()
#print(filtered_data)
# Out:
# Timestamp      19
# NAME           19
# CLASS/SEC      19
# ROLL NUMBER    19
# GENDER         19
# Q1             19
# Q2             19
# Q3             19
# Q4             19
# Q5             19
# Q6             19
# Q7             19
# Q8             19
# Data_N         19
# date           19
# dtype: int64

# %%
#filtered_data.plot(kind='hist')
filtered_data.head()
# Out:
#                           Timestamp              NAME    CLASS/SEC  \
# 3    2023/05/12 7:59:22 pm GMT+5:30         Vikranth     2 B.com C
# 6    2023/05/13 2:12:29 pm GMT+5:30      Shrujan J S   2nd BCOM'C'
# 8    2023/05/12 6:08:57 pm GMT+5:30          SHAMEER   1st b.com D
# 23   2023/05/12 7:52:18 pm GMT+5:30  Sharfuddeen S H   2nd year /D
# 40  2023/05/12 10:14:26 pm GMT+5:30      Melvin P Tom   2nd Bcom C
#
#     ROLL NUMBER  GENDER  Q1  Q2                                          Q3  \
# 3        210780       1   3   1                                           1
# 6        210774       1   3   1                                           1
# 8        220845       1   1   2  to share information and make connections.
# 23       210853       1   1   1                                           1
# 40       210787       1   3   1                                           3
#
#    Q4 Q5  Q6  Q7  Q8                    Data_N        date
# ...

# %%
filtered_data['Q5'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Q5'>

# %%
datag1 = data[(data['GENDER']==1)]
datag1.count()
#print(datag1)
# Out:
# Timestamp      56
# NAME           56
# CLASS/SEC      56
# ROLL NUMBER    56
# GENDER         56
# Q1             56
# Q2             56
# Q3             56
# Q4             56
# Q5             56
# Q6             56
# Q7             56
# Q8             56
# Data_N         56
# date           56
# dtype: int64

# %% [markdown]
# #   Q.3   Find the boys ,girls and All Student opinion  for  which one is more preferable social media sites for use?

# %%
datag1['Q1'].value_counts().plot(kind = 'pie')  # Boys opinion for  which one is more preferable social media sites for use
# Out:
# <Axes: ylabel='count'>

# %%
data['Q1'].value_counts().plot(kind = 'pie')   # All student opinion for  which one is more preferable social media sites for use
# Out:
# <Axes: ylabel='count'>

# %%
datag2 = data[data['GENDER'] == 2]
datag2.count()
# Out:
# Timestamp      94
# NAME           94
# CLASS/SEC      94
# ROLL NUMBER    94
# GENDER         94
# Q1             94
# Q2             94
# Q3             94
# Q4             94
# Q5             94
# Q6             94
# Q7             94
# Q8             94
# Data_N         94
# date           94
# dtype: int64

# %%
datag2['Q1'].value_counts().plot(kind = 'pie') # Only Girls opinion for which one is more preferable social media sites for use,
# Out:
# <Axes: ylabel='count'>

# %%
data.dtypes
# Out:
# Timestamp                         object
# NAME                              object
# CLASS/SEC                         object
# ROLL NUMBER                        int64
# GENDER                             int64
# Q1                                 int64
# Q2                                 int64
# Q3                                object
# Q4                                object
# Q5                                object
# Q6                                 int64
# Q7                                 int64
# Q8                                 int64
# Data_N         datetime64[ns, UTC-05:30]
# date                              object
# dtype: object

# %%
data.head()
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N  \
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30
# 3       210780       1   3   1  1  2  1   1   2   1 2023-05-12 19:59:22-05:30
# 4       210743       1   3   1  1  2  4   2   3   1 2023-05-12 20:00:24-05:30
#
#          date
# 0  2023-05-12
# 1  2023-05-12
# 2  2023-05-12
# ...

# %% [markdown]
# # Find total number  2nd year student  answer

# %%
filter = data[(data['ROLL NUMBER']>= 210000) & (data['ROLL NUMBER'] <= 219999)]
filter['NAME'].count()
# Out:
# 92

# %%
g1 =filter[filter['GENDER']==1]
g1['NAME'].count()
#print(g1)
# Out:
# 34

# %%
g2 = filter[filter['GENDER']== 2]
g2.count()
# Out:
# Timestamp      58
# NAME           58
# CLASS/SEC      58
# ROLL NUMBER    58
# GENDER         58
# Q1             58
# Q2             58
# Q3             58
# Q4             58
# Q5             58
# Q6             58
# Q7             58
# Q8             58
# Data_N         58
# date           58
# dtype: int64

# %%
filter['Q1'].value_counts().plot(kind ='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.groupby('Q6').Q6.count()
# Out:
# Q6
# 1    46
# 2    53
# 3    31
# 4    20
# Name: Q6, dtype: int64

# %%
data.groupby('Q5').Q5.count()
# Out:
# Q5
# 1                   14
# 2                   45
# 3                   18
# 4                   51
# 5                    4
# 6                   12
# Addictions           1
# All of the above     4
# Unwanted things      1
# Name: Q5, dtype: int64

# %%
filter.groupby('GENDER').GENDER.count() # It showS 2nd years student
# Out:
# GENDER
# 1    34
# 2    58
# Name: GENDER, dtype: int64

# %%
data.describe()
# Out:
#          ROLL NUMBER      GENDER          Q1          Q2          Q6  \
# count     150.000000  150.000000  150.000000  150.000000  150.000000
# mean   212019.613333    1.626667    2.820000    1.620000    2.166667
# std      6141.751040    0.485310    1.111683    0.816524    1.012782
# min    200242.000000    1.000000    1.000000    1.000000    1.000000
# 25%    210525.000000    1.000000    2.000000    1.000000    1.000000
# 50%    210762.500000    2.000000    3.000000    1.000000    2.000000
# 75%    220118.500000    2.000000    3.000000    2.000000    3.000000
# max    221067.000000    2.000000    6.000000    4.000000    4.000000
#
#                Q7          Q8
# count  150.000000  150.000000
# mean     2.206667    3.306667
# std      0.627092    1.164040
# min      1.000000    1.000000
# 25%      2.000000    2.000000
# 50%      2.000000    4.000000
# 75%      3.000000    4.000000
# max      3.000000    4.000000

# %%
data.head()
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N  \
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30
# 3       210780       1   3   1  1  2  1   1   2   1 2023-05-12 19:59:22-05:30
# 4       210743       1   3   1  1  2  4   2   3   1 2023-05-12 20:00:24-05:30
#
#          date
# 0  2023-05-12
# 1  2023-05-12
# 2  2023-05-12
# ...

# %%
data['Q6'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data.groupby('Q1')

# %%
data.groupby('Q1').Q1.count()
# Out:
# Q1
# 1     9
# 2    51
# 3    72
# 5    12
# 6     6
# Name: Q1, dtype: int64

# %%
sns.countplot(data['Q1'])
# Out:
# <Axes: ylabel='count'>

# %%
data['Year']=data['Data_N'].dt.year

# %%
data.head()
# Out:
#                         Timestamp                  NAME      CLASS/SEC  \
# 0  2023/05/12 8:29:52 pm GMT+5:30         Mukesh kulal   1st b.com 'C'
# 1  2023/05/12 9:15:04 pm GMT+5:30  Manaranjan Vernekar     2nd BCom D
# 2  2023/05/12 5:29:49 pm GMT+5:30              Vignesh       2nd Bsc B
# 3  2023/05/12 7:59:22 pm GMT+5:30             Vikranth       2 B.com C
# 4  2023/05/12 8:00:24 pm GMT+5:30              Nithin k         Bcom C
#
#    ROLL NUMBER  GENDER  Q1  Q2 Q3 Q4 Q5  Q6  Q7  Q8                    Data_N  \
# 0       220721       1   2   1  3  3  4   3   2   1 2023-05-12 20:29:52-05:30
# 1       210875       1   2   1  1  3  5   4   2   1 2023-05-12 21:15:04-05:30
# 2       210337       1   3   1  1  3  4   4   2   1 2023-05-12 17:29:49-05:30
# 3       210780       1   3   1  1  2  1   1   2   1 2023-05-12 19:59:22-05:30
# 4       210743       1   3   1  1  2  4   2   3   1 2023-05-12 20:00:24-05:30
#
#          date  Year
# 0  2023-05-12  2023
# 1  2023-05-12  2023
# ...

# %%
data.describe()
# Out:
#          ROLL NUMBER      GENDER          Q1          Q2          Q6  \
# count     150.000000  150.000000  150.000000  150.000000  150.000000
# mean   212019.613333    1.626667    2.820000    1.620000    2.166667
# std      6141.751040    0.485310    1.111683    0.816524    1.012782
# min    200242.000000    1.000000    1.000000    1.000000    1.000000
# 25%    210525.000000    1.000000    2.000000    1.000000    1.000000
# 50%    210762.500000    2.000000    3.000000    1.000000    2.000000
# 75%    220118.500000    2.000000    3.000000    2.000000    3.000000
# max    221067.000000    2.000000    6.000000    4.000000    4.000000
#
#                Q7          Q8        Year
# count  150.000000  150.000000  150.000000
# mean     2.206667    3.306667   12.413333
# std      0.627092    1.164040    0.696941
# min      1.000000    1.000000   11.000000
# 25%      2.000000    2.000000   12.000000
# 50%      2.000000    4.000000   12.000000
# 75%      3.000000    4.000000   13.000000
# ...
